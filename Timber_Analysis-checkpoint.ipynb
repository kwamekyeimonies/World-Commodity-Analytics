# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
Timber=pd.read_excel("Timber.xlsx",sheet_name="MonthlyPrices")
Timber
# Out:
#         Time  Sanwood_CMS  Sanwood_MYS     Plywood  WoodPulp
# 0    1960M01     0.000000   149.174978    0.000000       0.0
# 1    1960M02     0.000000   149.174978    0.000000       0.0
# 2    1960M03     0.000000   149.174978    0.000000       0.0
# 3    1960M04     0.000000   149.174978    0.000000       0.0
# 4    1960M05     0.000000   149.174978    0.000000       0.0
# 5    1960M06     0.000000   149.174978    0.000000       0.0
# 6    1960M07     0.000000   149.174978    0.000000       0.0
# 7    1960M08     0.000000   149.174978    0.000000       0.0
# 8    1960M09     0.000000   149.174978    0.000000       0.0
# 9    1960M10     0.000000   149.174978    0.000000       0.0
# 10   1960M11     0.000000   149.174978    0.000000       0.0
# 11   1960M12     0.000000   149.174978    0.000000       0.0
# 12   1961M01     0.000000   151.977281    0.000000       0.0
# 13   1961M02     0.000000   151.977281    0.000000       0.0
# ...

# %%
Timber.describe()
# Out:
#        Sanwood_CMS  Sanwood_MYS     Plywood    WoodPulp
# count   710.000000   710.000000  710.000000  710.000000
# mean    281.767095   478.952772  301.614640  442.718547
# std     325.187501   256.940164  234.805789  333.741117
# min       0.000000   141.305415    0.000000    0.000000
# 25%       0.000000   229.174229    0.000000    0.000000
# 50%       0.000000   461.538462  353.570000  521.005000
# 75%     583.237349   719.428247  501.001356  724.614185
# max    1087.540879   973.598500  751.810000  966.490000

# %%
Timber.describe()
# Out:
#        Sanwood_CMS  Sanwood_MYS     Plywood    WoodPulp
# count   710.000000   710.000000  710.000000  710.000000
# mean    281.767095   478.952772  301.614640  442.718547
# std     325.187501   256.940164  234.805789  333.741117
# min       0.000000   141.305415    0.000000    0.000000
# 25%       0.000000   229.174229    0.000000    0.000000
# 50%       0.000000   461.538462  353.570000  521.005000
# 75%     583.237349   719.428247  501.001356  724.614185
# max    1087.540879   973.598500  751.810000  966.490000

# %%
Timber_CMS=Timber[['Time','Sanwood_CMS']]
Timber_CMS
# Out:
#         Time  Sanwood_CMS
# 0    1960M01     0.000000
# 1    1960M02     0.000000
# 2    1960M03     0.000000
# 3    1960M04     0.000000
# 4    1960M05     0.000000
# 5    1960M06     0.000000
# 6    1960M07     0.000000
# 7    1960M08     0.000000
# 8    1960M09     0.000000
# 9    1960M10     0.000000
# 10   1960M11     0.000000
# 11   1960M12     0.000000
# 12   1961M01     0.000000
# 13   1961M02     0.000000
# 14   1961M03     0.000000
# 15   1961M04     0.000000
# 16   1961M05     0.000000
# 17   1961M06     0.000000
# 18   1961M07     0.000000
# 19   1961M08     0.000000
# 20   1961M09     0.000000
# 21   1961M10     0.000000
# 22   1961M11     0.000000
# 23   1961M12     0.000000
# 24   1962M01     0.000000
# 25   1962M02     0.000000
# 26   1962M03     0.000000
# 27   1962M04     0.000000
# 28   1962M05     0.000000
# 29   1962M06     0.000000
# ..       ...          ...
# 680  2016M09   630.037804
# 681  2016M10   591.609762
# 682  2016M11   595.490899
# ...

# %%
plt.figure(figsize=(20,20))
plt.plot(Timber_CMS['Time'],Timber_CMS['Sanwood_CMS'])
plt.xlabel('Time')
plt.ylabel('Sanwood CMS')
plt.title("Sanwood CMS Graph")
plt.show()

# %%
SanwoodCMS_Y=Timber_CMS[0:710:12]
SanwoodCMS_Y
# Out:
#         Time  Sanwood_CMS
# 0    1960M01     0.000000
# 12   1961M01     0.000000
# 24   1962M01     0.000000
# 36   1963M01     0.000000
# 48   1964M01     0.000000
# 60   1965M01     0.000000
# 72   1966M01     0.000000
# 84   1967M01     0.000000
# 96   1968M01     0.000000
# 108  1969M01     0.000000
# 120  1970M01   175.000000
# 132  1971M01     0.000000
# 144  1972M01     0.000000
# 156  1973M01     0.000000
# 168  1974M01     0.000000
# 180  1975M01     0.000000
# 192  1976M01     0.000000
# 204  1977M01     0.000000
# 216  1978M01     0.000000
# 228  1979M01     0.000000
# 240  1980M01   396.000000
# 252  1981M01     0.000000
# 264  1982M01     0.000000
# 276  1983M01     0.000000
# 288  1984M01     0.000000
# 300  1985M01     0.000000
# 312  1986M01     0.000000
# 324  1987M01     0.000000
# 336  1988M01     0.000000
# 348  1989M01     0.000000
# 360  1990M01   533.000000
# 372  1991M01     0.000000
# 384  1992M01     0.000000
# 396  1993M01     0.000000
# ...

# %%
Timber_MYS=Timber[['Time','Sanwood_MYS']]
Timber_MYS
# Out:
#         Time  Sanwood_MYS
# 0    1960M01   149.174978
# 1    1960M02   149.174978
# 2    1960M03   149.174978
# 3    1960M04   149.174978
# 4    1960M05   149.174978
# 5    1960M06   149.174978
# 6    1960M07   149.174978
# 7    1960M08   149.174978
# 8    1960M09   149.174978
# 9    1960M10   149.174978
# 10   1960M11   149.174978
# 11   1960M12   149.174978
# 12   1961M01   151.977281
# 13   1961M02   151.977281
# 14   1961M03   151.977281
# 15   1961M04   151.977281
# 16   1961M05   151.977281
# 17   1961M06   151.977281
# 18   1961M07   151.977281
# 19   1961M08   151.977281
# 20   1961M09   151.977281
# 21   1961M10   151.977281
# 22   1961M11   151.977281
# 23   1961M12   151.977281
# 24   1962M01   160.060969
# 25   1962M02   160.060969
# 26   1962M03   160.060969
# 27   1962M04   160.060969
# 28   1962M05   160.060969
# 29   1962M06   160.060969
# ..       ...          ...
# 680  2016M09   716.620500
# 681  2016M10   672.911500
# 682  2016M11   677.326000
# ...

# %%
plt.figure(figsize=(20,20))
plt.plot(Timber_MYS['Time'],Timber_MYS['Sanwood_MYS'])
plt.xlabel('Time')
plt.ylabel('Sanwood MYS')
plt.title("Sanwood MYS Graph")
plt.show()

# %%
SanwoodMYS_Y=Timber_MYS[0:710:12]
SanwoodMYS_Y
# Out:
#         Time  Sanwood_MYS
# 0    1960M01   149.174978
# 12   1961M01   151.977281
# 24   1962M01   160.060969
# 36   1963M01   160.724848
# 48   1964M01   151.280853
# 60   1965M01   145.659207
# 72   1966M01   159.394736
# 84   1967M01   161.362812
# 96   1968M01   172.210577
# 108  1969M01   165.908112
# 120  1970M01   165.908112
# 132  1971M01   178.300729
# 144  1972M01   169.242972
# 156  1973M01   187.647161
# 168  1974M01   269.392183
# 180  1975M01   225.088853
# 192  1976M01   233.448515
# 204  1977M01   264.119556
# 216  1978M01   267.051211
# 228  1979M01   299.616992
# 240  1980M01   401.817233
# 252  1981M01   363.658169
# 264  1982M01   360.018305
# 276  1983M01   338.337002
# 288  1984M01   356.827012
# 300  1985M01   305.471948
# 312  1986M01   337.658493
# 324  1987M01   367.945718
# 336  1988M01   441.982691
# 348  1989M01   401.014120
# 360  1990M01   571.443267
# 372  1991M01   515.086311
# 384  1992M01   577.778656
# 396  1993M01   605.355723
# ...

# %%
Timber_Plywood=Timber[['Time','Plywood']]
Timber_Plywood
# Out:
#         Time     Plywood
# 0    1960M01    0.000000
# 1    1960M02    0.000000
# 2    1960M03    0.000000
# 3    1960M04    0.000000
# 4    1960M05    0.000000
# 5    1960M06    0.000000
# 6    1960M07    0.000000
# 7    1960M08    0.000000
# 8    1960M09    0.000000
# 9    1960M10    0.000000
# 10   1960M11    0.000000
# 11   1960M12    0.000000
# 12   1961M01    0.000000
# 13   1961M02    0.000000
# 14   1961M03    0.000000
# 15   1961M04    0.000000
# 16   1961M05    0.000000
# 17   1961M06    0.000000
# 18   1961M07    0.000000
# 19   1961M08    0.000000
# 20   1961M09    0.000000
# 21   1961M10    0.000000
# 22   1961M11    0.000000
# 23   1961M12    0.000000
# 24   1962M01    0.000000
# 25   1962M02    0.000000
# 26   1962M03    0.000000
# 27   1962M04    0.000000
# 28   1962M05    0.000000
# 29   1962M06    0.000000
# ..       ...         ...
# 680  2016M09  535.870566
# 681  2016M10  526.163140
# 682  2016M11  504.669230
# 683  2016M12  470.329118
# 684  2017M01  474.332962
# ...

# %%
plt.figure(figsize=(20,20))
plt.plot(Timber_Plywood['Time'],Timber_Plywood['Plywood'])
plt.xlabel('Time')
plt.ylabel('Plywood')
plt.title("Plywood Graph")
plt.show()

# %%
Plywood_Y=Timber_Plywood[0:710:12]
Plywood_Y
# Out:
#         Time     Plywood
# 0    1960M01    0.000000
# 12   1961M01    0.000000
# 24   1962M01    0.000000
# 36   1963M01    0.000000
# 48   1964M01    0.000000
# 60   1965M01    0.000000
# 72   1966M01    0.000000
# 84   1967M01    0.000000
# 96   1968M01    0.000000
# 108  1969M01    0.000000
# 120  1970M01    0.000000
# 132  1971M01    0.000000
# 144  1972M01    0.000000
# 156  1973M01    0.000000
# 168  1974M01    0.000000
# 180  1975M01    0.000000
# 192  1976M01    0.000000
# 204  1977M01    0.000000
# 216  1978M01    0.000000
# 228  1979M01  270.000000
# 240  1980M01  285.800000
# 252  1981M01  258.900000
# 264  1982M01  255.470000
# 276  1983M01  244.700000
# 288  1984M01  222.320000
# 300  1985M01  202.610000
# 312  1986M01  242.420000
# 324  1987M01  373.830000
# 336  1988M01  414.510000
# 348  1989M01  363.510000
# 360  1990M01  317.040000
# 372  1991M01  362.260000
# 384  1992M01  403.710000
# 396  1993M01  511.960000
# 408  1994M01  564.970000
# 420  1995M01  551.010000
# ...

# %%
Timber_WoodPulp=Timber[['Time','WoodPulp']]
Timber_WoodPulp
# Out:
#         Time  WoodPulp
# 0    1960M01       0.0
# 1    1960M02       0.0
# 2    1960M03       0.0
# 3    1960M04       0.0
# 4    1960M05       0.0
# 5    1960M06       0.0
# 6    1960M07       0.0
# 7    1960M08       0.0
# 8    1960M09       0.0
# 9    1960M10       0.0
# 10   1960M11       0.0
# 11   1960M12       0.0
# 12   1961M01       0.0
# 13   1961M02       0.0
# 14   1961M03       0.0
# 15   1961M04       0.0
# 16   1961M05       0.0
# 17   1961M06       0.0
# 18   1961M07       0.0
# 19   1961M08       0.0
# 20   1961M09       0.0
# 21   1961M10       0.0
# 22   1961M11       0.0
# 23   1961M12       0.0
# 24   1962M01       0.0
# 25   1962M02       0.0
# 26   1962M03       0.0
# 27   1962M04       0.0
# 28   1962M05       0.0
# 29   1962M06       0.0
# ..       ...       ...
# 680  2016M09     875.0
# 681  2016M10     875.0
# 682  2016M11     875.0
# 683  2016M12     875.0
# 684  2017M01     875.0
# 685  2017M02     875.0
# 686  2017M03     875.0
# 687  2017M04     875.0
# ...

# %%
plt.figure(figsize=(20,20))
plt.plot(Timber_WoodPulp['Time'],Timber_WoodPulp['WoodPulp'])
plt.xlabel('Time')
plt.ylabel('WoodPulp')
plt.title("WoodPulp Graph")
plt.show()

# %%
WoodPulp=Timber_WoodPulp[0:710:12]
WoodPulp
# Out:
#         Time    WoodPulp
# 0    1960M01    0.000000
# 12   1961M01    0.000000
# 24   1962M01    0.000000
# 36   1963M01    0.000000
# 48   1964M01    0.000000
# 60   1965M01    0.000000
# 72   1966M01    0.000000
# 84   1967M01    0.000000
# 96   1968M01    0.000000
# 108  1969M01    0.000000
# 120  1970M01    0.000000
# 132  1971M01    0.000000
# 144  1972M01    0.000000
# 156  1973M01    0.000000
# 168  1974M01    0.000000
# 180  1975M01    0.000000
# 192  1976M01    0.000000
# 204  1977M01    0.000000
# 216  1978M01    0.000000
# 228  1979M01  410.000000
# 240  1980M01  505.000000
# 252  1981M01  545.200000
# 264  1982M01  547.500000
# 276  1983M01  408.980000
# 288  1984M01  456.780000
# 300  1985M01  438.430000
# 312  1986M01  427.610000
# 324  1987M01  542.930000
# 336  1988M01  714.420000
# 348  1989M01  788.680000
# 360  1990M01  857.080000
# 372  1991M01  721.850000
# 384  1992M01  517.310000
# 396  1993M01  476.540000
# 408  1994M01  431.300000
# 420  1995M01  690.450000
# ...

# %%
plt.figure(figsize=(20,20))
plt.plot(Timber_CMS.Sanwood_CMS,color="red")
plt.plot(Timber_MYS.Sanwood_MYS,color="black")
plt.plot(Timber_Plywood.Plywood,color="green")
plt.plot(Timber_WoodPulp.WoodPulp,color="yellow")
plt.legend(["Sanwood_CMS","Sanwood_MYS","Plywood","WoodPulp"])
plt.grid(True)
plt.show()
